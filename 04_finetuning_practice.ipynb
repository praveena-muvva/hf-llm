# %% [markdown]
# <a href="https://colab.research.google.com/github/praveena-muvva/hf-llm/blob/main/04_finetuning_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Finetuning steps
#Step 1: Loading data - (load_data("imdb"))
#Step 2: Preprocessing - (tokenizer = AutoTokenizer.from_pretrained(checkpoint), tokenizer(...))
#Step 3: Training
# - Load model - (AutoModelForSequenceClassification.from_pretrained("..." ...))
# - Training arguments - (TrainingArguments(output_dir, eval_strategy, learning_rate, batch_size, epochs, weight_decay ..))
# - Trainer - (Trainer(model, args, train_dataset, eval_dataset ..))
#trainer.train()
#Step 4: Evaluation - (trainer.evaluate())
